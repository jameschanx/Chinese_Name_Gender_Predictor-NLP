# %%
from xpinyin import Pinyin
import pandas as pd
from keras.layers import LSTM
from keras.models import Sequential
import string

# %%
p = Pinyin()
df = pd.read_csv('ChineseNames.csv')

# %%
#change headers to english
df.columns = ['Name', 'Gender']

# %%
#strip last name
def strip_last_name(name):
    return name[1:]

def convert_to_pinyin(name):
    return p.get_pinyin(name)

def process_name(name):
    name = strip_last_name(name)
    name = convert_to_pinyin(name)
    return name

# %%
print(df.tail(20))
df['Name'] = df['Name'].apply(process_name)
print(df.tail(20))
# Out:
#      Name Gender
# 9780  邹明昊      M
# 9781  邹念龙      M
# 9782  邹世博      M
# 9783   邹思      M
# 9784   邹旭      M
# 9785   邹弋      M
# 9786  邹宇涵      M
# 9787  邹智高      M
# 9788  邹钟毓      M
# 9789   邹舟      M
# 9790  俎富豪      M
# 9791  祖新瑞      M
# 9792  左佳奇      M
# 9793  左建飞      M
# 9794  左金明      M
# 9795  左奎峰      M
# 9796   左堃      M
# 9797  左世靖      M
# 9798  左世良      M
# 9799  左天佑      M
#            Name Gender
# 9780   ming-hao      M
# 9781  nian-long      M
# 9782     shi-bo      M
# 9783         si      M
# 9784         xu      M
# 9785         yi      M
# 9786     yu-han      M
# 9787    zhi-gao      M
# 9788   zhong-yu      M
# 9789       zhou      M
# 9790     fu-hao      M
# 9791    xin-rui      M
# 9792     jia-qi      M
# 9793   jian-fei      M
# 9794   jin-ming      M
# 9795   kui-feng      M
# 9796        kun      M
# 9797   shi-jing      M
# 9798  shi-liang      M
# 9799   tian-you      M

# %%
#get all unique chars
characters = {}
for i, name in enumerate(df['Name']):
    for char in name:
        if char == ' ':
            print(i,name)
        if char in characters:
            characters[char] += 1
        else:
            characters[char] = 1
print(characters)
# Out:
# 8012
# {'y': 3347, 'i': 8056, 'z': 1215, 'h': 3212, 'a': 5261, 'n': 8640, 'g': 4079, '-': 7272, 'x': 1569, 'j': 1488, 'w': 717, 'e': 3269, 'l': 968, 'm': 669, 'o': 2421, 'q': 782, 'r': 546, 'd': 406, 'u': 3975, 's': 784, 'f': 481, 'c': 796, 't': 546, 'b': 349, 'p': 258, 'k': 322, '夑': 1, 'v': 5, '\ue10e': 1, ' ': 1}

# %%
#find the longest name
maxlen = df['Name'].str.len().max()

# %%
def char_to_vec(char):
# Out:
# array([ 2,  8,  3,  4,  7,  9,  6, 10,  5, 12, 11,  1, 13, 16, 14],
#       dtype=int64)

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
model = Sequential()
model.add(LSTM(1, input_shape=(50, 500), return_sequ.ences=False)
model.compile(loss='categorical_crossentropy', optimizer='adam')
# Out:
#             Name Gender
# 0             yi      F
# 1       zhang-xi      F
# 2       jing-wen      F
# 3            lan      F
# 4            man      F
# 5       meng-yao      F
# 6           qiao      F
# 7            ran      F
# 8           yang      F
# 9             yi      F
# 10          ying      F
# 11            di      F
# 12           rui      F
# 13            di      F
# 14       hao-yue      F
# 15       hua-lin      F
# 16     jiao-jiao      F
# 17       li-qing      F
# 18       luo-lan      F
# 19       qiao-zi      F
# 20      qing-wen      F
# 21      shen-hao      F
# 22        yi-fan      F
# 23        yi-han      F
# 24      yue-ling      F
# 25           yue      F
# 26        zi-wei      F
# 27        yu-wei      F
# 28    cheng-yang      F
# 29        li-man      F
# ...          ...    ...
# 9770      ze-hao      M
# 9771    zhi-chao      M
# 9772        chen      M
# 9773          yi      M
# 9774    bao-ming      M
# 9775   bing-yang      M
# 9776     cai-wen      M
# 9777     hao-lin      M
# 9778   jia-cheng      M
# 9779         lei      M
# 9780    ming-hao      M
# 9781   nian-long      M
# 9782      shi-bo      M
# 9783          si      M
# 9784          xu      M
# 9785          yi      M
# 9786      yu-han      M
# 9787     zhi-gao      M
# 9788    zhong-yu      M
# 9789        zhou      M
# 9790      fu-hao      M
# 9791     xin-rui      M
# 9792      jia-qi      M
# 9793    jian-fei      M
# 9794    jin-ming      M
# 9795    kui-feng      M
# 9796         kun      M
# 9797    shi-jing      M
# 9798   shi-liang      M
# 9799    tian-you      M
#
# [9800 rows x 2 columns]
